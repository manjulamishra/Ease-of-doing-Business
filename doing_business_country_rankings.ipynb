# %%
#importing the required libaries 
from __future__ import print_function, division
import pandas as pd

from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Doing Business data from the World Bank
doing_biz = pd.read_excel('/home/mishraka/Documents/Manjula/Lambda_School/Hackathon_Project_datasets/Doing_Business/Rankings.xlsx')

# %%
doing_biz.head()
# Out:
#                 Economy  globalRank  Starting a Business  \
# 0           New Zealand           1                    1
# 1             Singapore           2                    3
# 2               Denmark           3                   42
# 3  Hong Kong SAR, China           4                    5
# 4           Korea, Rep.           5                   11
#
#    Dealing with Construction Permits  Getting Electricity  \
# 0                                  6                   45
# 1                                  8                   16
# 2                                  4                   21
# 3                                  1                    3
# 4                                 10                    2
#
#    Registering Property  Getting Credit  Protecting Minority Investors  \
# 0                     1               1                              2
# 1                    21              32                              7
# ...

# %%
doing_biz.shape
# Out:
# (190, 12)

# %%
doing_biz.isna().sum()
# Out:
# Economy                              0
# globalRank                           0
# Starting a Business                  0
# Dealing with Construction Permits    0
# Getting Electricity                  0
# Registering Property                 0
# Getting Credit                       0
# Protecting Minority Investors        0
# Paying Taxes                         0
# Trading across Borders               0
# Enforcing Contracts                  0
# Resolving Insolvency                 0
# dtype: int64

# %%
#since that dataframe doesn't have info about continents,
#I downloaded another df containing info about the countries and continents
continents = pd.read_excel('/home/mishraka/Documents/Manjula/Lambda_School/Hackathon_Project_datasets/Doing_Business/countries.xlsx', sheet_name= 'sheet_1')

# %%
continents.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName
# 0  SNA data for 2000-2011 are updated from offici...        Aruba
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan
# 2                                                NaN       Angola
# 3                                                NaN      Albania
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra

# %%
continents.isna().sum()
# Out:
# Country Code      0
# Region           46
# IncomeGroup      46
# SpecialNotes    115
# TableName         0
# dtype: int64

# %%
continents.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName'], dtype='object')

# %%
#realized I didn't have to do it
#but for convinience, lets change the column names
continents_updated = continents.rename(index=str, columns={'Country Code': 'country_code', 
                                                           'Region': 'region', "IncomeGroup": 'income_group',
                                                           'SpecialNotes': 'special_notes',
                                                           'TableName': 'table_name'})

# %%
continents_updated.columns
# Out:
# Index(['country_code', 'region', 'income_group', 'special_notes',
#        'table_name'],
#       dtype='object')

# %%
continents_updated.head()
# Out:
#   country_code                     region         income_group  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                        special_notes   table_name
# 0  SNA data for 2000-2011 are updated from offici...        Aruba
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan
# 2                                                NaN       Angola
# 3                                                NaN      Albania
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra

# %%
#drop the columns I don't need
continents_new = continents_updated.drop(columns = ['income_group', 'special_notes'])

# %%
continents_new.head()
# Out:
#   country_code                     region   table_name
# 0          ABW  Latin America & Caribbean        Aruba
# 1          AFG                 South Asia  Afghanistan
# 2          AGO         Sub-Saharan Africa       Angola
# 3          ALB      Europe & Central Asia      Albania
# 4          AND      Europe & Central Asia      Andorra

# %%
continents_new.shape
# Out:
# (263, 3)

# %%
#checking for any duplicate columns
continents_new.drop_duplicates()
# Out:
#     country_code                      region  \
# 0            ABW   Latin America & Caribbean
# 1            AFG                  South Asia
# 2            AGO          Sub-Saharan Africa
# 3            ALB       Europe & Central Asia
# 4            AND       Europe & Central Asia
# 5            ARB                         NaN
# 6            ARE  Middle East & North Africa
# 7            ARG   Latin America & Caribbean
# 8            ARM       Europe & Central Asia
# 9            ASM         East Asia & Pacific
# 10           ATG   Latin America & Caribbean
# 11           AUS         East Asia & Pacific
# 12           AUT       Europe & Central Asia
# 13           AZE       Europe & Central Asia
# 14           BDI          Sub-Saharan Africa
# 15           BEL       Europe & Central Asia
# 16           BEN          Sub-Saharan Africa
# 17           BFA          Sub-Saharan Africa
# 18           BGD                  South Asia
# 19           BGR       Europe & Central Asia
# ...

# %%
#unnecessary but lets put the df in an order
continents_new.sort_values(by='table_name', ascending=True)
# Out:
#     country_code                      region                table_name
# 1            AFG                  South Asia               Afghanistan
# 3            ALB       Europe & Central Asia                   Albania
# 58           DZA  Middle East & North Africa                   Algeria
# 9            ASM         East Asia & Pacific            American Samoa
# 4            AND       Europe & Central Asia                   Andorra
# 2            AGO          Sub-Saharan Africa                    Angola
# 10           ATG   Latin America & Caribbean       Antigua and Barbuda
# 5            ARB                         NaN                Arab World
# 7            ARG   Latin America & Caribbean                 Argentina
# 8            ARM       Europe & Central Asia                   Armenia
# 0            ABW   Latin America & Caribbean                     Aruba
# 11           AUS         East Asia & Pacific                 Australia
# ...

# %%
#quickly check how df looks using groupby
grouped_continent_new = continents_new.groupby([ "region", "table_name"]).count()

# %%
grouped_continent_new
# Out:
#                                                country_code
# region              table_name
# East Asia & Pacific American Samoa                        1
#                     Australia                             1
#                     Brunei Darussalam                     1
#                     Cambodia                              1
#                     China                                 1
#                     Fiji                                  1
#                     French Polynesia                      1
#                     Guam                                  1
#                     Hong Kong SAR, China                  1
#                     Indonesia                             1
#                     Japan                                 1
#                     Kiribati                              1
#                     Korea, Dem. People's Rep.             1
#                     Korea, Rep.                           1
# ...

# %% [markdown]
# <span class="mark">This was a very important discovery to be able to make dictionary</span>

# %%
#convert country name and continent into dictonary format
continent_dict = dict(zip(continents_new.table_name, continents_new.region))

# %%
continent_dict
# Out:
# {'Aruba': 'Latin America & Caribbean',
#  'Afghanistan': 'South Asia',
#  'Angola': 'Sub-Saharan Africa',
#  'Albania': 'Europe & Central Asia',
#  'Andorra': 'Europe & Central Asia',
#  'Arab World': nan,
#  'United Arab Emirates': 'Middle East & North Africa',
#  'Argentina': 'Latin America & Caribbean',
#  'Armenia': 'Europe & Central Asia',
#  'American Samoa': 'East Asia & Pacific',
#  'Antigua and Barbuda': 'Latin America & Caribbean',
#  'Australia': 'East Asia & Pacific',
#  'Austria': 'Europe & Central Asia',
#  'Azerbaijan': 'Europe & Central Asia',
#  'Burundi': 'Sub-Saharan Africa',
#  'Belgium': 'Europe & Central Asia',
#  'Benin': 'Sub-Saharan Africa',
#  'Burkina Faso': 'Sub-Saharan Africa',
#  'Bangladesh': 'South Asia',
#  'Bulgaria': 'Europe & Central Asia',
#  'Bahrain': 'Middle East & North Africa',
#  'Bahamas, The': 'Latin America & Caribbean',
#  'Bosnia and Herzegovina': 'Europe & Central Asia',
#  'Belarus': 'Europe & Central Asia',
# ...

# %%
#make a new df with only Economy(name of countries)
doing_biz_country_names = doing_biz[['Economy']]

# %%
doing_biz_country_names.shape
# Out:
# (190, 1)

# %%
doing_biz_country_names.columns
# Out:
# Index(['Economy'], dtype='object')

# %%
doing_biz_country_names.sort_values(by='Economy', ascending=True)
# Out:
#                     Economy
# 166             Afghanistan
# 62                  Albania
# 156                 Algeria
# 172                  Angola
# 111     Antigua and Barbuda
# 118               Argentina
# 40                  Armenia
# 17                Australia
# 25                  Austria
# 24               Azerbaijan
# 117            Bahamas, The
# 61                  Bahrain
# 175              Bangladesh
# 128                Barbados
# 36                  Belarus
# 44                  Belgium
# 124                  Belize
# 152                   Benin
# 80                   Bhutan
# 155                 Bolivia
# 88   Bosnia and Herzegovina
# 85                 Botswana
# 108                  Brazil
# 54        Brunei Darussalam
# 58                 Bulgaria
# 150            Burkina Faso
# 167                 Burundi
# 130              Cabo Verde
# 137                Cambodia
# 165                Cameroon
# ..                      ...
# 161                   Sudan
# ...

# %% [markdown]
# Below, I thought of using the method to create a column of the same length, realized there is a better way to do it

# %%
# # mask = (doing_biz_country_names['continent'])
# # doing_biz_country_names['Continent']  = pd.Categorical(np.where(mask, 'continent_name'))

# mask = doing_biz_country_names.continent.between(1,191)
# doing_biz_country_names['Continent']  = pd.Categorical(np.where(mask,'continent_name', "continent_name" ))
# print (doing_biz_country_names)

# %%
# doing_biz_contries = doing_biz_country_names.drop(columns = ['continent'])

# %%
# doing_biz_contries.shape

# %%
# doing_biz_contries

# %%
print(continent_dict)
# Out:
# {'Aruba': 'Latin America & Caribbean', 'Afghanistan': 'South Asia', 'Angola': 'Sub-Saharan Africa', 'Albania': 'Europe & Central Asia', 'Andorra': 'Europe & Central Asia', 'Arab World': nan, 'United Arab Emirates': 'Middle East & North Africa', 'Argentina': 'Latin America & Caribbean', 'Armenia': 'Europe & Central Asia', 'American Samoa': 'East Asia & Pacific', 'Antigua and Barbuda': 'Latin America & Caribbean', 'Australia': 'East Asia & Pacific', 'Austria': 'Europe & Central Asia', 'Azerbaijan': 'Europe & Central Asia', 'Burundi': 'Sub-Saharan Africa', 'Belgium': 'Europe & Central Asia', 'Benin': 'Sub-Saharan Africa', 'Burkina Faso': 'Sub-Saharan Africa', 'Bangladesh': 'South Asia', 'Bulgaria': 'Europe & Central Asia', 'Bahrain': 'Middle East & North Africa', 'Bahamas, The': 'Latin America & Caribbean', 'Bosnia and Herzegovina': 'Europe & Central Asia', 'Belarus': 'Europe & Central Asia', 'Belize': 'Latin America & Caribbean', 'Bermuda': 'North America', 'Bolivia': 'Latin America & 
# ...

# %%
doing_biz_country_names['continent']= doing_biz_country_names['Economy'].map(continent_dict)
# Out:
# /home/mishraka/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
doing_biz_country_names
# Out:
#                       Economy                   continent
# 0                 New Zealand         East Asia & Pacific
# 1                   Singapore         East Asia & Pacific
# 2                     Denmark       Europe & Central Asia
# 3        Hong Kong SAR, China         East Asia & Pacific
# 4                 Korea, Rep.         East Asia & Pacific
# 5                     Georgia       Europe & Central Asia
# 6                      Norway       Europe & Central Asia
# 7               United States               North America
# 8              United Kingdom       Europe & Central Asia
# 9              Macedonia, FYR       Europe & Central Asia
# 10       United Arab Emirates  Middle East & North Africa
# 11                     Sweden       Europe & Central Asia
# 12              Taiwan, China                         NaN
# 13                  Lithuania       Europe & Central Asia
# 14                   Malaysia         East Asia & Pacific
# ...

# %%
doing_biz_country_names.isna().sum()
# Out:
# Economy      0
# continent    3
# dtype: int64

# %%
doing_biz_country_names = doing_biz_country_names.drop(columns=['Economy'])

# %%
df = pd.concat([doing_biz_country_names,doing_biz], axis=1)

# %%
df
# Out:
#                       continent                   Economy  globalRank  \
# 0           East Asia & Pacific               New Zealand           1
# 1           East Asia & Pacific                 Singapore           2
# 2         Europe & Central Asia                   Denmark           3
# 3           East Asia & Pacific      Hong Kong SAR, China           4
# 4           East Asia & Pacific               Korea, Rep.           5
# 5         Europe & Central Asia                   Georgia           6
# 6         Europe & Central Asia                    Norway           7
# 7                 North America             United States           8
# 8         Europe & Central Asia            United Kingdom           9
# 9         Europe & Central Asia            Macedonia, FYR          10
# 10   Middle East & North Africa      United Arab Emirates          11
# 11        Europe & Central Asia                    Sweden          12
# ...

# %%
df.isna().sum()
# Out:
# continent                            3
# Economy                              0
# globalRank                           0
# Starting a Business                  0
# Dealing with Construction Permits    0
# Getting Electricity                  0
# Registering Property                 0
# Getting Credit                       0
# Protecting Minority Investors        0
# Paying Taxes                         0
# Trading across Borders               0
# Enforcing Contracts                  0
# Resolving Insolvency                 0
# dtype: int64

# %%
null_data = df[df.isnull().any(axis=1)]

# %%
null_data
# Out:
#     continent                Economy  globalRank  Starting a Business  \
# 12        NaN          Taiwan, China          13                   20
# 63        NaN     Puerto Rico (U.S.)          64                   53
# 169       NaN  São Tomé and Príncipe         170                  148
#
#      Dealing with Construction Permits  Getting Electricity  \
# 12                                   2                    8
# 63                                 141                   88
# 169                                111                  125
#
#      Registering Property  Getting Credit  Protecting Minority Investors  \
# 12                     19              99                             15
# 63                    159               3                            110
# 169                   173             161                            188
#
#      Paying Taxes  Trading across Borders  Enforcing Contracts  \
# 12             29                      58                   11
# ...

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# continent                            0
# Economy                              0
# globalRank                           0
# Starting a Business                  0
# Dealing with Construction Permits    0
# Getting Electricity                  0
# Registering Property                 0
# Getting Credit                       0
# Protecting Minority Investors        0
# Paying Taxes                         0
# Trading across Borders               0
# Enforcing Contracts                  0
# Resolving Insolvency                 0
# dtype: int64

# %%
df.shape
# Out:
# (187, 13)

# %%
df.columns
# Out:
# Index(['continent', 'Economy', 'globalRank', 'Starting a Business',
#        'Dealing with Construction Permits', 'Getting Electricity',
#        'Registering Property', 'Getting Credit',
#        'Protecting Minority Investors', 'Paying Taxes',
#        'Trading across Borders', 'Enforcing Contracts',
#        'Resolving Insolvency'],
#       dtype='object')

# %%
df.dtypes
# Out:
# continent                            object
# Economy                              object
# globalRank                            int64
# Starting a Business                   int64
# Dealing with Construction Permits     int64
# Getting Electricity                   int64
# Registering Property                  int64
# Getting Credit                        int64
# Protecting Minority Investors         int64
# Paying Taxes                          int64
# Trading across Borders                int64
# Enforcing Contracts                   int64
# Resolving Insolvency                  int64
# dtype: object

# %%
df_temp = df[['Economy']]

# %%
df_temp.columns
# Out:
# Index(['Economy'], dtype='object')

# %% [markdown]
# Now I realize that it might be a good idea to have a GDP column in df for vizualization
# so let's import another Excel datafile which contains GDP for 2017 for all these countries

# %%
#this files contains the info on GDP
gdp_countries = pd.read_excel('/home/mishraka/Documents/Manjula/Lambda_School/Hackathon_Project_datasets/Doing_Business/countries.xlsx', sheet_name= 'Sheet4')

# %%
gdp_countries.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1  59.777327  59.878153  58.492874  78.782758  82.208444  101.290471
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#        ...               2008          2009          2010          2011  \
# ...

# %%
gdp_countries.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
#make a new df with only country name and GDP in 2017 columns
gdp_df = gdp_countries[['Country Name', '2017']]

# %%
gdp_df
# Out:
#                                           Country Name          2017
# 0                                                Aruba           NaN
# 1                                          Afghanistan    585.850064
# 2                                               Angola   4170.312280
# 3                                              Albania   4537.862492
# 4                                              Andorra  39146.548836
# 5                                           Arab World   6251.141575
# 6                                 United Arab Emirates  40698.849336
# 7                                            Argentina  14401.974855
# 8                                              Armenia   3936.798320
# 9                                       American Samoa           NaN
# 10                                 Antigua and Barbuda  15021.738183
# 11                                           Australia  53799.938090
# 12                                             Austria  47290.911650
# ...

# %%
gdp_dict = dict(zip(gdp_df['Country Name'], gdp_df['2017']))

# %%
gdp_dict
# Out:
# {'Aruba': nan,
#  'Afghanistan': 585.85006378237,
#  'Angola': 4170.31228024945,
#  'Albania': 4537.8624924478,
#  'Andorra': 39146.5488360905,
#  'Arab World': 6251.1415751198,
#  'United Arab Emirates': 40698.8493360368,
#  'Argentina': 14401.9748546081,
#  'Armenia': 3936.79831965287,
#  'American Samoa': nan,
#  'Antigua and Barbuda': 15021.7381833074,
#  'Australia': 53799.9380899599,
#  'Austria': 47290.9116498316,
#  'Azerbaijan': 4131.61831005055,
#  'Burundi': 320.086870120894,
#  'Belgium': 43323.8073364711,
#  'Benin': 829.797230600794,
#  'Burkina Faso': 670.705913111953,
#  'Bangladesh': 1516.51342307197,
#  'Bulgaria': 8031.59844245699,
#  'Bahrain': 23655.0356024012,
#  'Bahamas, The': 30762.0124392644,
#  'Bosnia and Herzegovina': 5180.63630093473,
#  'Belarus': 5726.02967250931,
#  'Belize': 4905.50628401227,
#  'Bermuda': nan,
#  'Bolivia': 3393.95581751781,
#  'Brazil': 9821.40768641008,
#  'Barbados': 16788.6839195944,
#  'Brunei Darussalam': 28290.5851955712,
# ...

# %%
#gdp_df['GDP_2017']= gdp_df['Economy'].map(continent_dict)
# http://cmdlinetips.com/2018/01/how-to-add-a-new-column-to-using-a-dictionary-in-pandas-data-frame/
df_temp['2017']= df_temp['Economy'].map(gdp_dict)
# Out:
# /home/mishraka/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_temp.head()
# Out:
#                 Economy          2017
# 0           New Zealand  42940.578288
# 1             Singapore  57714.296631
# 2               Denmark  56307.508300
# 3  Hong Kong SAR, China  46193.614520
# 4           Korea, Rep.  29742.838861

# %%
df_gdp_2017 = df_temp.drop(columns='Economy')

# %%
df_final = pd.concat([df,df_gdp_2017], axis=1)

# %%
df_final
# Out:
#                       continent                   Economy  globalRank  \
# 0           East Asia & Pacific               New Zealand           1
# 1           East Asia & Pacific                 Singapore           2
# 2         Europe & Central Asia                   Denmark           3
# 3           East Asia & Pacific      Hong Kong SAR, China           4
# 4           East Asia & Pacific               Korea, Rep.           5
# 5         Europe & Central Asia                   Georgia           6
# 6         Europe & Central Asia                    Norway           7
# 7                 North America             United States           8
# 8         Europe & Central Asia            United Kingdom           9
# 9         Europe & Central Asia            Macedonia, FYR          10
# 10   Middle East & North Africa      United Arab Emirates          11
# 11        Europe & Central Asia                    Sweden          12
# ...

# %%
df_final.dtypes
# Out:
# continent                             object
# Economy                               object
# globalRank                             int64
# Starting a Business                    int64
# Dealing with Construction Permits      int64
# Getting Electricity                    int64
# Registering Property                   int64
# Getting Credit                         int64
# Protecting Minority Investors          int64
# Paying Taxes                           int64
# Trading across Borders                 int64
# Enforcing Contracts                    int64
# Resolving Insolvency                   int64
# 2017                                 float64
# dtype: object

# %%
df_final['2017'] = df_final['2017'].round()

# %%
print(df_final['2017'])
# Out:
# 0      42941.0
# 1      57714.0
# 2      56308.0
# 3      46194.0
# 4      29743.0
# 5       4078.0
# 6      75505.0
# 7      59532.0
# 8      39720.0
# 9       5443.0
# 10     40699.0
# 11     53442.0
# 13     16681.0
# 14      9945.0
# 15     19705.0
# 16     45703.0
# 17     53800.0
# 18     15594.0
# 19     10547.0
# 20     70057.0
# 21     45032.0
# 22     69331.0
# 23     44470.0
# 24      4132.0
# 25     47291.0
# 26      6594.0
# 27      8837.0
# 28       748.0
# 29     28157.0
# 30     10743.0
#         ...
# 159     3188.0
# 160      450.0
# 161     2899.0
# 162      499.0
# 163      797.0
# 164     5901.0
# 165     1447.0
# 166      586.0
# 167      320.0
# 168     7221.0
# 170     1299.0
# 171     5166.0
# 172     4170.0
# 173      456.0
# 174      724.0
# 175     1517.0
# 176     9850.0
# 177     2279.0
# 178        NaN
# 179     1658.0
# 180      670.0
# 181      766.0
# 182      418.0
# 183      458.0
# 184        NaN
# 185     7998.0
# 186        NaN
# 187        NaN
# ...

# %%
df_final = df_final.rename(columns = {'2017':'gdp_2017'})

# %%
df_final.columns
# Out:
# Index(['continent', 'Economy', 'globalRank', 'Starting a Business',
#        'Dealing with Construction Permits', 'Getting Electricity',
#        'Registering Property', 'Getting Credit',
#        'Protecting Minority Investors', 'Paying Taxes',
#        'Trading across Borders', 'Enforcing Contracts', 'Resolving Insolvency',
#        'gdp_2017'],
#       dtype='object')

# %%
df_final.isna().sum()
# Out:
# continent                            0
# Economy                              0
# globalRank                           0
# Starting a Business                  0
# Dealing with Construction Permits    0
# Getting Electricity                  0
# Registering Property                 0
# Getting Credit                       0
# Protecting Minority Investors        0
# Paying Taxes                         0
# Trading across Borders               0
# Enforcing Contracts                  0
# Resolving Insolvency                 0
# gdp_2017                             6
# dtype: int64

# %%
null_data = df_final[df_final.isnull().any(axis=1)]

# %%
null_data
# Out:
#                       continent               Economy  globalRank  \
# 121          Sub-Saharan Africa         Côte d'Ivoire         122
# 178  Middle East & North Africa  Syrian Arab Republic         179
# 184          Sub-Saharan Africa           South Sudan         185
# 186  Middle East & North Africa           Yemen, Rep.         187
# 187   Latin America & Caribbean         Venezuela, RB         188
# 188          Sub-Saharan Africa               Eritrea         189
#
#      Starting a Business  Dealing with Construction Permits  \
# 121                   26                                142
# 178                  136                                186
# 184                  177                                169
# 186                  175                                186
# 187                  190                                152
# 188                  187                                186
#
#      Getting Electricity  Registering Property  Getting Credit  \
# ...

# %%
df_ranking = df_final.dropna()

# %%
df_ranking.shape
# Out:
# (181, 14)

# %%
df_ranking.isna().sum()
# Out:
# continent                            0
# Economy                              0
# globalRank                           0
# Starting a Business                  0
# Dealing with Construction Permits    0
# Getting Electricity                  0
# Registering Property                 0
# Getting Credit                       0
# Protecting Minority Investors        0
# Paying Taxes                         0
# Trading across Borders               0
# Enforcing Contracts                  0
# Resolving Insolvency                 0
# gdp_2017                             0
# dtype: int64

# %%
df = df_ranking

# %%
df.head()
# Out:
#                continent               Economy  globalRank  \
# 0    East Asia & Pacific           New Zealand           1
# 1    East Asia & Pacific             Singapore           2
# 2  Europe & Central Asia               Denmark           3
# 3    East Asia & Pacific  Hong Kong SAR, China           4
# 4    East Asia & Pacific           Korea, Rep.           5
#
#    Starting a Business  Dealing with Construction Permits  \
# 0                    1                                  6
# 1                    3                                  8
# 2                   42                                  4
# 3                    5                                  1
# 4                   11                                 10
#
#    Getting Electricity  Registering Property  Getting Credit  \
# 0                   45                     1               1
# 1                   16                    21              32
# 2                   21                    11              44
# ...

# %% [markdown]
# <div class="mark">
# Import lesson: how to save the files i created here in jupyter to save them on local machine</div><i class="fa fa-lightbulb-o "></i>

# %%
# https://medium.com/ibm-data-science-experience/how-to-upload-download-files-to-from-notebook-in-my-local-machine-6a4e65a15767
import base64  
import pandas as pd

# %%
#write dataframe to file
df.to_csv("test1.csv")  
#read it back
pd.read_csv("test1.csv").head()
# Out:
#    Unnamed: 0              continent               Economy  globalRank  \
# 0           0    East Asia & Pacific           New Zealand           1
# 1           1    East Asia & Pacific             Singapore           2
# 2           2  Europe & Central Asia               Denmark           3
# 3           3    East Asia & Pacific  Hong Kong SAR, China           4
# 4           4    East Asia & Pacific           Korea, Rep.           5
#
#    Starting a Business  Dealing with Construction Permits  \
# 0                    1                                  6
# 1                    3                                  8
# 2                   42                                  4
# 3                    5                                  1
# 4                   11                                 10
#
#    Getting Electricity  Registering Property  Getting Credit  \
# 0                   45                     1               1
# 1                   16                    21              32
# ...

# %%
from IPython.display import HTML

def create_download_link( df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(df)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
from jupyter_plotly_dash import JupyterDash

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.plotly as py
import plotly.graph_objs as go
import plotly

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = JupyterDash('SimpleExample')

app.layout = html.Div([
    dcc.Graph(
        id='life-exp-vs-gdp',
        figure={
            'data': [
                go.Scatter(
                    x=df['gdp_2017'],
                    y=df['globalRank'],
                    text=df['Economy'],
                    mode='markers',
                    opacity=0.7,
                    marker={
                        'size': 15,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    
                ) 
            ],
            'layout': go.Layout(
                xaxis={'type': 'log', 'title': 'GDP Per Capita'},
                yaxis={'title': 'Global Ranking'},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                legend={'x': 0, 'y': 1},
                hovermode='closest'
            )
        }
    )
])

app
# Out:
# <div>
#   <iframe src="/app/endpoints/3ccfbca377314bc685fed5bef2da8297/" width=800 height=600 frameborder="0"></iframe>
#   <hr/><a href="/app/endpoints/3ccfbca377314bc685fed5bef2da8297/" target="_new">Open in new window</a> for /app/endpoints/3ccfbca377314bc685fed5bef2da8297/
# </div>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd
import math

#data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv")
#df_2007 = data[data['year']==2007]
df_2017 = df.sort_values(['continent', 'Economy'])
slope = 2.666051223553066e-05
hover_text = []
bubble_size = []

for index, row in df_2007.iterrows():
    hover_text.append(('Country: {country}<br>'+
                      'Life Expectancy: {lifeExp}<br>'+
                      'GDP per capita: {gdp}<br>'+
                      'Population: {pop}<br>'+
                      'Year: {year}').format(country=row['country'],
                                            lifeExp=row['lifeExp'],
                                            gdp=row['gdpPercap'],
                                            pop=row['pop'],
                                            year=row['year']))
    bubble_size.append(math.sqrt(row['pop']*slope))

df_2007['text'] = hover_text
df_2007['size'] = bubble_size
sizeref = 2.*max(df_2007['size'])/(100**2)

trace0 = go.Scatter(
    x=df_2007['gdpPercap'][df_2007['continent'] == 'Africa'],
    y=df_2007['lifeExp'][df_2007['continent'] == 'Africa'],
    mode='markers',
    name='Africa',
    text=df_2007['text'][df_2007['continent'] == 'Africa'],
    marker=dict(
        symbol='circle',
        sizemode='area',
        sizeref=sizeref,
        size=df_2007['size'][df_2007['continent'] == 'Africa'],
        line=dict(
            width=2
        ),
    )
)
trace1 = go.Scatter(
    x=df_2007['gdpPercap'][df_2007['continent'] == 'Americas'],
    y=df_2007['lifeExp'][df_2007['continent'] == 'Americas'],
    mode='markers',
    name='Americas',
    text=df_2007['text'][df_2007['continent'] == 'Americas'],
    marker=dict(
        sizemode='area',
        sizeref=sizeref,
        size=df_2007['size'][df_2007['continent'] == 'Americas'],
        line=dict(
            width=2
        ),
    )
)
trace2 = go.Scatter(
    x=df_2007['gdpPercap'][df_2007['continent'] == 'Asia'],
    y=df_2007['lifeExp'][df_2007['continent'] == 'Asia'],
    mode='markers',
    name='Asia',
    text=df_2007['text'][df_2007['continent'] == 'Asia'],
    marker=dict(
        sizemode='area',
        sizeref=sizeref,
        size=df_2007['size'][df_2007['continent'] == 'Asia'],
        line=dict(
            width=2
        ),
    )
)
trace3 = go.Scatter(
    x=df_2007['gdpPercap'][df_2007['continent'] == 'Europe'],
    y=df_2007['lifeExp'][df_2007['continent'] == 'Europe'],
    mode='markers',
    name='Europe',
    text=df_2007['text'][df_2007['continent'] == 'Europe'],
    marker=dict(
        sizemode='area',
        sizeref=sizeref,
        size=df_2007['size'][df_2007['continent'] == 'Europe'],
        line=dict(
            width=2
        ),
    )
)
trace4 = go.Scatter(
    x=df_2007['gdpPercap'][df_2007['continent'] == 'Oceania'],
    y=df_2007['lifeExp'][df_2007['continent'] == 'Oceania'],
    mode='markers',
    name='Oceania',
    text=df_2007['text'][df_2007['continent'] == 'Oceania'],
    marker=dict(
        sizemode='area',
        sizeref=sizeref,
        size=df_2007['size'][df_2007['continent'] == 'Oceania'],
        line=dict(
            width=2
        ),
    )
)

data = [trace0, trace1, trace2, trace3, trace4]
layout = go.Layout(
    title='Life Expectancy v. Per Capita GDP, 2007',
    xaxis=dict(
        title='GDP per capita (2000 dollars)',
        gridcolor='rgb(255, 255, 255)',
        range=[2.003297660701705, 5.191505530708712],
        type='log',
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    yaxis=dict(
        title='Life Expectancy (years)',
        gridcolor='rgb(255, 255, 255)',
        range=[36.12621671352166, 91.72921793264332],
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='life-expectancy-per-GDP-2007')
